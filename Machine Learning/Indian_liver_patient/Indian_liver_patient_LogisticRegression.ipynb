# %%
from lazypredict.Supervised import LazyClassifier
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv("Indian_liver_patient.csv")

# %%
df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female             0.70              0.10                   187
# 1     62    Male            10.90              5.50                   699
# 2     62    Male             7.30              4.10                   490
# 3     58    Male             1.00              0.40                   182
# 4     72    Male             3.90              2.00                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male             0.50              0.10                   500
# 579   40    Male             0.60              0.10                    98
# 580   52    Male             0.80              0.20                   245
# 581   31    Male             1.30              0.50                   184
# 582   38    Male             1.00              0.30                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18            6.80
# 1                          64                         100            7.50
# 2                          60                          68            7.00
# 3                          14                          20            6.80
# 4                          27                          59            7.30
# ..                        ...                         ...             ...
# 578                        20                          34            5.90
# 579                        35                          31            6.00
# 580                        48                          49            6.40
# 581                        29                          32            6.80
# 582                        21                          24            7.30
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0       3.30                        0.90        1
# 1       3.20                        0.74        1
# 2       3.30                        0.89        1
# 3       3.40                        1.00        1
# 4       2.40                        0.40        1
# ..       ...                         ...      ...
# 578     1.60                        0.37        2
# 579     3.20                        1.10        1
# 580     3.20                        1.00        1
# 581     3.40                        1.00        1
# 582     4.40                        1.50        2
#
# [583 rows x 11 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
df["Albumin_and_Globulin_Ratio"] = df.Albumin_and_Globulin_Ratio.fillna(df['Albumin_and_Globulin_Ratio'].mean())

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
df['Dataset'] = df['Dataset'].replace(2,0)
df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female             0.70              0.10                   187
# 1     62    Male            10.90              5.50                   699
# 2     62    Male             7.30              4.10                   490
# 3     58    Male             1.00              0.40                   182
# 4     72    Male             3.90              2.00                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male             0.50              0.10                   500
# 579   40    Male             0.60              0.10                    98
# 580   52    Male             0.80              0.20                   245
# 581   31    Male             1.30              0.50                   184
# 582   38    Male             1.00              0.30                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18            6.80
# 1                          64                         100            7.50
# 2                          60                          68            7.00
# 3                          14                          20            6.80
# 4                          27                          59            7.30
# ..                        ...                         ...             ...
# 578                        20                          34            5.90
# 579                        35                          31            6.00
# 580                        48                          49            6.40
# 581                        29                          32            6.80
# 582                        21                          24            7.30
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0       3.30                        0.90        1
# 1       3.20                        0.74        1
# 2       3.30                        0.89        1
# 3       3.40                        1.00        1
# 4       2.40                        0.40        1
# ..       ...                         ...      ...
# 578     1.60                        0.37        0
# 579     3.20                        1.10        1
# 580     3.20                        1.00        1
# 581     3.40                        1.00        1
# 582     4.40                        1.50        0
#
# [583 rows x 11 columns]

# %%
y=df['Dataset']
X=df.drop(['Dataset','Gender'],axis=1)

# %%
X
# Out:
#      Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65             0.70              0.10                   187
# 1     62            10.90              5.50                   699
# 2     62             7.30              4.10                   490
# 3     58             1.00              0.40                   182
# 4     72             3.90              2.00                   195
# ..   ...              ...               ...                   ...
# 578   60             0.50              0.10                   500
# 579   40             0.60              0.10                    98
# 580   52             0.80              0.20                   245
# 581   31             1.30              0.50                   184
# 582   38             1.00              0.30                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18            6.80
# 1                          64                         100            7.50
# 2                          60                          68            7.00
# 3                          14                          20            6.80
# 4                          27                          59            7.30
# ..                        ...                         ...             ...
# 578                        20                          34            5.90
# 579                        35                          31            6.00
# 580                        48                          49            6.40
# 581                        29                          32            6.80
# 582                        21                          24            7.30
#
#      Albumin  Albumin_and_Globulin_Ratio
# 0       3.30                        0.90
# 1       3.20                        0.74
# 2       3.30                        0.89
# 3       3.40                        1.00
# 4       2.40                        0.40
# ..       ...                         ...
# 578     1.60                        0.37
# 579     3.20                        1.10
# 580     3.20                        1.00
# 581     3.40                        1.00
# 582     4.40                        1.50
#
# [583 rows x 9 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 578    0
# 579    1
# 580    1
# 581    1
# 582    0
# Name: Dataset, Length: 583, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state =123)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Lazy Prediction to find the optimal algorithm

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train_scaled, X_test_scaled, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:03<00:00,  7.68it/s]
# [LightGBM] [Info] Number of positive: 336, number of negative: 130
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000410 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 539
# [LightGBM] [Info] Number of data points in the train set: 466, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.721030 -> initscore=0.949577
# [LightGBM] [Info] Start training from score 0.949577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# GaussianNB                         0.63               0.73     0.73      0.63
# SGDClassifier                      0.74               0.71     0.71      0.75
# QuadraticDiscriminantAnalysis      0.62               0.70     0.70      0.62
# ExtraTreeClassifier                0.73               0.68     0.68      0.73
# PassiveAggressiveClassifier        0.73               0.68     0.68      0.72
# NearestCentroid                    0.57               0.63     0.63      0.58
# ExtraTreesClassifier               0.72               0.63     0.63      0.70
# LabelPropagation                   0.68               0.61     0.61      0.67
# RandomForestClassifier             0.69               0.60     0.60      0.67
# LogisticRegression                 0.74               0.60     0.60      0.68
# BernoulliNB                        0.62               0.59     0.59      0.63
# LabelSpreading                     0.67               0.59     0.59      0.66
# KNeighborsClassifier               0.69               0.59     0.59      0.66
# Perceptron                         0.70               0.59     0.59      0.67
# LinearSVC                          0.73               0.58     0.58      0.66
# XGBClassifier                      0.68               0.57     0.57      0.65
# LGBMClassifier                     0.66               0.55     0.55      0.63
# AdaBoostClassifier                 0.66               0.55     0.55      0.63
# NuSVC                              0.67               0.55     0.55      0.63
# BaggingClassifier                  0.61               0.54     0.54      0.60
# DecisionTreeClassifier             0.64               0.53     0.53      0.61
# LinearDiscriminantAnalysis         0.69               0.53     0.53      0.60
# CalibratedClassifierCV             0.69               0.53     0.53      0.60
# RidgeClassifierCV                  0.68               0.51     0.51      0.57
# RidgeClassifier                    0.68               0.50     0.50      0.57
# DummyClassifier                    0.68               0.50     0.50      0.56
# SVC                                0.68               0.50     0.50      0.56
#
#                                Time Taken
# Model
# GaussianNB                           0.06
# SGDClassifier                        0.05
# QuadraticDiscriminantAnalysis        0.03
# ExtraTreeClassifier                  0.05
# PassiveAggressiveClassifier          0.03
# NearestCentroid                      0.05
# ExtraTreesClassifier                 0.62
# LabelPropagation                     0.08
# RandomForestClassifier               0.90
# LogisticRegression                   0.08
# BernoulliNB                          0.04
# LabelSpreading                       0.07
# KNeighborsClassifier                 0.05
# Perceptron                           0.04
# LinearSVC                            0.10
# XGBClassifier                        0.18
# LGBMClassifier                       0.18
# AdaBoostClassifier                   0.39
# NuSVC                                0.11
# BaggingClassifier                    0.20
# DecisionTreeClassifier               0.05
# LinearDiscriminantAnalysis           0.05
# CalibratedClassifierCV               0.09
# RidgeClassifierCV                    0.05
# RidgeClassifier                      0.05
# DummyClassifier                      0.04
# SVC                                  0.08

# %% [markdown]
# ### Logistic Regression

# %%
model = LogisticRegression()
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.7350427350427351
